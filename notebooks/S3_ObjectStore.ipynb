# %%
import boto3
from botocore.client import Config

ACCESS_KEY = "AKIATFYH3HIBNOO3DOF5"
SECRET_KEY = "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"
REGION = "us-east-1"
BUCKET = "hcp-2a044ffd-9fa3-46b4-b670-15d8733de468"

s3 = boto3.client(
    's3',
    aws_access_key_id=ACCESS_KEY,
    aws_secret_access_key=SECRET_KEY,
    region_name=REGION,
    endpoint_url="https://s3.amazonaws.com",  # important
    config=Config(signature_version='s3v4')
)

prefix = "quality/default/"
resp = s3.list_objects_v2(Bucket=BUCKET, Prefix=prefix)
if 'Contents' in resp:
    for obj in resp['Contents']:
        print(obj['Key'], obj['Size'])
else:
    print("No objects found under", prefix)
# Out:
# quality/default/qualitymodel.tar.gz 29

# %%
ACCESS_KEY = "AKIATFYH3HIBJDELKXXX"
SECRET_KEY = "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"
BUCKET = "hcp-2a044ffd-9fa3-46b4-b670-15d8733de468"
REGION = "us-east-1"

# %%
import boto3
from botocore.client import Config

# standard AWS S3 endpoint
s3 = boto3.client(
    's3',
    aws_access_key_id=ACCESS_KEY,
    aws_secret_access_key=SECRET_KEY,
    region_name=REGION,
    config=Config(signature_version='s3v4')
)

# list objects under prefix (adjust prefix if needed)
prefix = "quality/default/"
resp = s3.list_objects_v2(Bucket=BUCKET, Prefix=prefix)
if 'Contents' in resp:
    for obj in resp['Contents']:
        print(obj['Key'], obj['Size'])
else:
    print("No objects found under", prefix)

# optionally download a known key
key = prefix + "qualitymodel.tar.gz"  # change if you saw a different filename
try:
    s3.download_file(BUCKET, key, "downloaded_model.tar.gz")
    print("Downloaded", key, "-> downloaded_model.tar.gz")
except Exception as e:
    print("Download failed:", e)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[11], line 15
#      13 # list objects under prefix (adjust prefix if needed)
#      14 prefix = "quality/default/"
# ---> 15 resp = s3.list_objects_v2(Bucket=BUCKET, Prefix=prefix)
#      16 if 'Contents' in resp:
#      17     for obj in resp['Contents']:
#
# File ~/envs/timeseries/lib/python3.13/site-packages/botocore/client.py:602, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     598     raise TypeError(
#     599         f"{py_operation_name}() only accepts keyword arguments."
#     600     )
#     601 # The "self" in this scope is referring to the BaseClient.
# --> 602 return self._make_api_call(operation_name, kwargs)
#
# File ~/envs/timeseries/lib/python3.13/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
# ...
